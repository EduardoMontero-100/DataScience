# %% [markdown]
# ## Pandas Visualizacion

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline # mostrar los graficos en la notebook

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# escojemos este color palette
plt.style.use('seaborn-colorblind')

# %%
## Dataframe.plot
np.random.seed(123)

df = pd.DataFrame(
{
    'A': np.random.randn(365).cumsum(0),
    'B': np.random.randn(365).cumsum(0) + 20,
    'C': np.random.randn(365).cumsum(0) - 20
},
index = pd.date_range('1/1/2017', periods=365)
)

df.head()
# Out:
#                    A          B          C
# 2017-01-01 -1.085631  20.059291 -20.230904
# 2017-01-02 -0.088285  21.803332 -16.659325
# 2017-01-03  0.194693  20.835588 -17.055481
# 2017-01-04 -1.311601  21.255156 -17.093802
# 2017-01-05 -1.890202  21.462083 -19.518638

# %%
df.plot();

# %%
df.plot('A', 'B', kind = 'scatter');

# %%
df.plot.scatter('A', 'C', c = 'B', s = df['B'], colormap = 'viridis')
# Out:
# <AxesSubplot:xlabel='A', ylabel='C'>

# %%
ax = df.plot.scatter('A', 'C', c = 'B', s = df['B'], colormap = 'viridis')
ax.set_aspect('equal')

# %%
df.plot.box();

# %%
df.plot.hist();

# %%
df.plot.kde();

# %%
## pandas.tools.plotting
from sklearn.datasets import load_iris

# %%
iris = load_iris()
#column_names = df.target_names.tolist()
#column_names.append('target')
#column_names

# %%
df = pd.read_csv('/media/eduardo/Datos/Datasets/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
pd.plotting.scatter_matrix(df);

# %%
pd.plotting.parallel_coordinates(df ,'Name'); # falta añadir el campo que identifica el tipo
